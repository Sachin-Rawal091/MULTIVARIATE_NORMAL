# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
weight = np.random.normal(loc=70,scale=5,size=500)
height = (-2*weight + 5)+np.random.normal(loc=20,scale=9,size=500)
data = pd.DataFrame({"Weight (Kgs)":weight,"Height (Cms)":height})
data
# Out:
#      Weight (Kgs)  Height (Cms)
# 0       68.092476   -104.827435
# 1       73.970095   -138.466687
# 2       72.658368   -126.849789
# 3       64.959712   -106.403983
# 4       70.614065   -117.203344
# ..            ...           ...
# 495     71.257368   -128.657543
# 496     79.567235   -133.039850
# 497     72.767437   -121.484238
# 498     78.455162   -122.849326
# 499     65.334820   -104.158955
#
# [500 rows x 2 columns]

# %%
plt.xlabel("Weight (Kgs)")
plt.ylabel("Height (Cms)")
plt.scatter(data['Weight (Kgs)'],data['Height (Cms)'])

# %%
print(np.mean(data['Height (Cms)']))
print(np.mean(data['Weight (Kgs)']))
# Out:
# -116.0977875309278
# 70.36693429482375
