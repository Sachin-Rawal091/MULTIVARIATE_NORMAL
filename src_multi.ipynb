# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
weight = np.random.normal(loc=70,scale=5,size=500)
height = np.random.normal(loc=170,scale=8,size=500)
data = pd.DataFrame({"Weight (Kgs)":weight,"Height (Cms)":height})
data
# Out:
#      Weight (Kgs)  Height (Cms)
# 0       64.596054    164.649381
# 1       69.138689    183.629179
# 2       66.806767    167.427631
# 3       71.506603    173.621033
# 4       67.383830    180.155787
# ..            ...           ...
# 495     72.734215    190.276054
# 496     73.146486    160.481800
# 497     72.436315    175.729279
# 498     76.850173    187.527562
# 499     79.324265    176.722403
#
# [500 rows x 2 columns]

# %%
plt.xlabel("Weight (Kgs)")
plt.ylabel("Height (Cms)")
plt.scatter(data['Weight (Kgs)'],data['Height (Cms)'])

# %%
print(np.mean(data['Height (Cms)']))
print(np.mean(data['Weight (Kgs)']))
